# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

#Reading Data
data = pd.read_csv('/home/chathushka/Desktop/Reaserch/testData.csv')
print(data.shape)
data.head()
# Out:
# (5100, 26)
#    totalviews_channelelapsedtime                 channelid  videocategoryid  \
# 0                       0.165199  UCdzU3DSGzyWzN2118yd9X9g               22
# 1                       1.133820  UC0UnhAG47DRyVZGVcbhAXhQ               10
# 2                       0.668120  UCXjtAvK5P3wXBGh0vbGylzg               27
# 3                      16.517982  UCpjYH_3HgCYCBEj5kOZ250A               26
# 4                       0.839871  UCBFF3y6p-LqzD9bQSDgipgA               24
#
#    channelviewcount  likes_subscriber  views_subscribers  videocount  \
# 0             14654          0.555556          95.111111          30
# 1            105909          0.239130          59.326087          51
# 2             48265          0.023669          10.289941          72
# 3            625569          0.060052          11.130610         310
# 4             37895          0.237363          22.301099           8
#
#    subscribercount      videoid  dislikes_views  ...  comments_views  \
# ...

# %%
videocategoryid = data['videocategoryid'].values
videoviewcount = data['videoviewcount'].values
videocommentcount = data['videocommentcount'].values
videolikecount = data['videolikecount'].values
videodislikecount = data['videodislikecount'].values
videoPublishYear = data['videopublished'].values

n= len(videocategoryid)

#declare Four variables(TotalViews,TotalComment,TotalLikes and TotalDislike) for each YouTube video categories

cat1TotalViews=0
cat2TotalViews=0
cat10TotalViews=0
cat15TotalViews=0
cat17TotalViews=0
cat19TotalViews=0
cat20TotalViews=0
cat22TotalViews=0
cat23TotalViews=0
cat24TotalViews=0
cat25TotalViews=0
cat26TotalViews=0
cat27TotalViews=0
cat28TotalViews=0
cat29TotalViews=0

cat1TotalComments=0
cat2TotalComments=0
cat10TotalComments=0
cat15TotalComments=0
cat17TotalComments=0
cat19TotalComments=0
cat20TotalComments=0
cat22TotalComments=0
cat23TotalComments=0
cat24TotalComments=0
cat25TotalComments=0
cat26TotalComments=0
cat27TotalComments=0
cat28TotalComments=0
cat29TotalComments=0

cat1TotalLikes=0
cat2TotalLikes=0
cat10TotalLikes=0
cat15TotalLikes=0
cat17TotalLikes=0
cat19TotalLikes=0
cat20TotalLikes=0
cat22TotalLikes=0
cat23TotalLikes=0
cat24TotalLikes=0
cat25TotalLikes=0
cat26TotalLikes=0
cat27TotalLikes=0
cat28TotalLikes=0
cat29TotalLikes=0

cat1TotalDislike=0
cat2TotalDislike=0
cat10TotalDislike=0
cat15TotalDislike=0
cat17TotalDislike=0
cat19TotalDislike=0
cat20TotalDislike=0
cat22TotalDislike=0
cat23TotalDislike=0
cat24TotalDislike=0
cat25TotalDislike=0
cat26TotalDislike=0
cat27TotalDislike=0
cat28TotalDislike=0
cat29TotalDislike=0



#find total views, total comment, total likes and total dislike for each video categories in my testing data
for i in range(n):
    year=videoPublishYear[i]
    year=year[0:4]
    if(year=='2013'):

        if(videocategoryid[i]==1):
            cat1TotalViews+= videoviewcount[i]
            cat1TotalComments+=videocommentcount[i]
            cat1TotalLikes+=videolikecount[i]
            cat1TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==2):
            cat2TotalViews+= videoviewcount[i]
            cat2TotalComments+=videocommentcount[i]
            cat2TotalLikes+=videolikecount[i]
            cat2TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==10):
            cat10TotalViews+= videoviewcount[i]
            cat10TotalComments+=videocommentcount[i]
            cat10TotalLikes+=videolikecount[i]
            cat10TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==15):
            cat15TotalViews+= videoviewcount[i]
            cat15TotalComments+=videocommentcount[i]
            cat15TotalLikes+=videolikecount[i]
            cat15TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==17):
            cat17TotalViews+= videoviewcount[i]
            cat17TotalComments+=videocommentcount[i]
            cat17TotalLikes+=videolikecount[i]
            cat17TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==19):
            cat19TotalViews+= videoviewcount[i]
            cat19TotalComments+=videocommentcount[i]
            cat19TotalLikes+=videolikecount[i]
            cat19TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==20):
            cat20TotalViews+= videoviewcount[i]
            cat20TotalComments+=videocommentcount[i]
            cat20TotalLikes+=videolikecount[i]
            cat20TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==22):
            cat22TotalViews+= videoviewcount[i]
            cat22TotalComments+=videocommentcount[i]
            cat22TotalLikes+=videolikecount[i]
            cat22TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==23):
            cat23TotalViews+= videoviewcount[i]
            cat23TotalComments+=videocommentcount[i]
            cat23TotalLikes+=videolikecount[i]
            cat23TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==24):
            cat24TotalViews+= videoviewcount[i]
            cat24TotalComments+=videocommentcount[i]
            cat24TotalLikes+=videolikecount[i]
            cat24TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==25):
            cat25TotalViews+= videoviewcount[i]
            cat25TotalComments+=videocommentcount[i]
            cat25TotalLikes+=videolikecount[i]
            cat25TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==26):
            cat26TotalViews+= videoviewcount[i]
            cat26TotalComments+=videocommentcount[i]
            cat26TotalLikes+=videolikecount[i]
            cat26TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==27):
            cat27TotalViews+= videoviewcount[i]
            cat27TotalComments+=videocommentcount[i]
            cat27TotalLikes+=videolikecount[i]
            cat27TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==28):
            cat28TotalViews+= videoviewcount[i]
            cat28TotalComments+=videocommentcount[i]
            cat28TotalLikes+=videolikecount[i]
            cat28TotalDislike+=videodislikecount[i]

        elif(videocategoryid[i]==29):
            cat29TotalViews+= videoviewcount[i]
            cat29TotalComments+=videocommentcount[i]
            cat29TotalLikes+=videolikecount[i]
            cat29TotalDislike+=videodislikecount[i]

# %%
#Diclare new value calld Populrity Value for each Youtubecategories

popCat1Value=0
popCat2Value=0
popCat10Value=0
popCat15Value=0
popCat17Value=0
popCat19Value=0
popCat20Value=0
popCat22Value=0
popCat23Value=0
popCat24Value=0
popCat25Value=0
popCat26Value=0
popCat27Value=0
popCat28Value=0
popCat29Value=0


#calculate Popularity value for each video categories using relationship which is found from linear regrassion

popCat1Value+=cat1TotalViews/10000
#popCat1Value+=cat1TotalComments/5.5
popCat1Value+=cat1TotalLikes/89.7
popCat1Value-=cat1TotalDislike/3.9
popCat1Value=math.floor(popCat1Value)
if(popCat1Value<0):
    popCat1Value=1

popCat2Value+=cat2TotalViews/10000
#popCat2Value+=cat2TotalComments/5.5
popCat2Value+=cat2TotalLikes/89.7
popCat2Value-=cat2TotalDislike/3.9
popCat2Value=math.floor(popCat2Value)
if(popCat2Value<0):
    popCat2Value=1

popCat10Value+=cat10TotalViews/10000
#popCat10Value+=cat10TotalComments/5.5
popCat10Value+=cat10TotalLikes/89.7
popCat10Value-=cat10TotalDislike/3.9
popCat10Value=math.floor(popCat10Value)
if(popCat10Value<0):
    popCat10Value=1

popCat15Value+=cat15TotalViews/10000
#popCat15Value+=cat15TotalComments/5.5
popCat15Value+=cat15TotalLikes/89.7
popCat15Value-=cat15TotalDislike/3.9
popCat15Value=math.floor(popCat15Value)
if(popCat15Value<0):
    popCat15Value=1

popCat17Value+=cat17TotalViews/10000
#popCat17Value+=cat17TotalComments/5.5
popCat17Value+=cat17TotalLikes/89.7
popCat17Value-=cat17TotalDislike/3.9
popCat17Value=math.floor(popCat17Value)
if(popCat17Value<0):
    popCat17Value=1

popCat19Value+=cat19TotalViews/10000
#popCat19Value+=cat19TotalComments/5.5
popCat19Value+=cat19TotalLikes/89.7
popCat19Value-=cat19TotalDislike/3.9
popCat19Value=math.floor(popCat19Value)
if(popCat19Value<0):
    popCat19Value=1

popCat20Value+=cat20TotalViews/10000
#popCat20Value+=cat20TotalComments/5.5
popCat20Value+=cat20TotalLikes/89.7
popCat20Value-=cat20TotalDislike/3.9
popCat20Value=math.floor(popCat20Value)
if(popCat20Value<0):
    popCat20Value=1

popCat22Value+=cat22TotalViews/10000
#popCat22Value+=cat22TotalComments/5.5
popCat22Value+=cat22TotalLikes/89.7
popCat22Value-=cat22TotalDislike/3.9
popCat22Value=math.floor(popCat22Value)
if(popCat22Value<0):
    popCat22Value=1

popCat23Value+=cat23TotalViews/10000
#popCat23Value+=cat23TotalComments/5.5
popCat23Value+=cat23TotalLikes/89.7
popCat23Value-=cat23TotalDislike/3.9
popCat23Value=math.floor(popCat23Value)
if(popCat23Value<0):
    popCat23Value=1

popCat24Value+=cat24TotalViews/10000
#popCat24Value+=cat24TotalComments/5.5
popCat24Value+=cat24TotalLikes/89.7
popCat24Value-=cat24TotalDislike/3.9
popCat24Value=math.floor(popCat24Value)
if(popCat24Value<0):
    popCat24Value=1

popCat25Value+=cat25TotalViews/10000
#popCat25Value+=cat25TotalComments/5.5
popCat25Value+=cat25TotalLikes/89.7
popCat25Value-=cat25TotalDislike/3.9
popCat25Value=math.floor(popCat25Value)
if(popCat25Value<0):
    popCat25Value=1

popCat26Value+=cat26TotalViews/10000
#popCat26Value+=cat26TotalComments/5.5
popCat26Value+=cat26TotalLikes/89.7
popCat26Value-=cat26TotalDislike/3.9
popCat26Value=math.floor(popCat26Value)
if(popCat26Value<0):
    popCat26Value=1

popCat27Value+=cat27TotalViews/10000
#popCat27Value+=cat27TotalComments/5.5
popCat27Value+=cat27TotalLikes/89.7
popCat27Value-=cat27TotalDislike/3.9
popCat27Value=math.floor(popCat27Value)
if(popCat27Value<0):
    popCat27Value=1

popCat28Value+=cat28TotalViews/10000
#popCat28Value+=cat28TotalComments/5.5
popCat28Value+=cat28TotalLikes/89.7
popCat28Value-=cat28TotalDislike/3.9
popCat28Value=math.floor(popCat28Value)
if(popCat28Value<0):
    popCat28Value=1

popCat29Value+=cat29TotalViews/10000
#popCat29Value+=cat29TotalComments/5.5
popCat29Value+=cat29TotalLikes/89.7
popCat29Value-=cat29TotalDislike/3.9
popCat29Value=math.floor(popCat29Value)
if(popCat29Value<0):
    popCat29Value=1



Total_popularity = popCat1Value+popCat2Value+popCat10Value+popCat15Value+popCat17Value+popCat19Value+popCat20Value
Total_popularity+= popCat22Value+popCat23Value+popCat24Value+popCat25Value+popCat26Value+popCat27Value         
Total_popularity+= popCat28Value+popCat29Value

#print(Total_popularity)

cat1PopPrecentage = (popCat1Value/Total_popularity)*100
cat2PopPrecentage = (popCat2Value/Total_popularity)*100
cat10PopPrecentage = (popCat10Value/Total_popularity)*100
cat15PopPrecentage = (popCat15Value/Total_popularity)*100
cat17PopPrecentage = (popCat17Value/Total_popularity)*100
cat19PopPrecentage = (popCat19Value/Total_popularity)*100
cat20PopPrecentage = (popCat20Value/Total_popularity)*100
cat22PopPrecentage = (popCat22Value/Total_popularity)*100
cat23PopPrecentage = (popCat23Value/Total_popularity)*100
cat24PopPrecentage = (popCat24Value/Total_popularity)*100
cat25PopPrecentage = (popCat25Value/Total_popularity)*100
cat26PopPrecentage = (popCat26Value/Total_popularity)*100
cat27PopPrecentage = (popCat27Value/Total_popularity)*100
cat28PopPrecentage = (popCat28Value/Total_popularity)*100
cat29PopPrecentage = (popCat29Value/Total_popularity)*100

# %%
#Draw popularity distrbution graph

plt.figure(figsize=(10,7))
objects = ('Film & Animation', 'Autos & Vehicle', 'Music', 'Pets & Animals', 'Sports', 'Travel Event', 'Gaming',
           'People & Blog', 'Comedy', 'Entertainment', 'News $ Politics', 'Howto & Style', 'Education', 
           'Science & Technology', 'Nonprofit & Activism')
y_pos = np.arange(len(objects))
performance = [cat1PopPrecentage,cat2PopPrecentage,cat10PopPrecentage,cat15PopPrecentage,cat17PopPrecentage,cat19PopPrecentage,cat20PopPrecentage,
               cat22PopPrecentage,cat23PopPrecentage,cat24PopPrecentage,cat25PopPrecentage,cat26PopPrecentage,cat27PopPrecentage,cat28PopPrecentage,
               cat29PopPrecentage]

plt.bar(y_pos, performance, align='center', alpha=1)
plt.xticks(y_pos, objects, rotation='vertical')
plt.ylabel('Popularity Precentage %')
plt.title('Popularity Distribution Of YouTube video categories in 2013')

plt.show()
