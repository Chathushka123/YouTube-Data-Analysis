# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Reading Data
data = pd.read_csv('/home/chathushka/Desktop/Reaserch/mydata.csv')
print(data.shape)
data.head()
# Out:
# (50000, 26)
#    totalviews_channelelapsedtime                 channelid  videocategoryid  \
# 0                       0.165199  UCdzU3DSGzyWzN2118yd9X9g               22
# 1                       1.133820  UC0UnhAG47DRyVZGVcbhAXhQ               10
# 2                       0.668120  UCXjtAvK5P3wXBGh0vbGylzg               27
# 3                      16.517982  UCpjYH_3HgCYCBEj5kOZ250A               26
# 4                       0.839871  UCBFF3y6p-LqzD9bQSDgipgA               24
#
#    channelviewcount  likes_subscriber  views_subscribers  videocount  \
# 0             14654          0.555556          95.111111          30
# 1            105909          0.239130          59.326087          51
# 2             48265          0.023669          10.289941          72
# 3            625569          0.060052          11.130610         310
# 4             37895          0.237363          22.301099           8
#
#    subscribercount      videoid  dislikes_views  ...  comments_views  \
# ...

# %%
#Calculatin X and Y
X = data['videoviewcount'].values
Y = data['videodislikecount'].values 
videocategoryid = data['videocategoryid'].values

point = 0;
traindataViews = [0]*11086
traindataDislike = [0]*11086
for i in range(len(X)):
    if(videocategoryid[i]==10):
        traindataViews[point] = X[i]
        traindataDislike[point] = Y[i]
        point+=1
    elif(videocategoryid[i]==23):
        traindataViews[point] = X[i]
        traindataDislike[point] = Y[i]
        point+=1
    elif(videocategoryid[i]==29):
        traindataViews[point] = X[i]
        traindataDislike[point] = Y[i]
        point+=1

# %%
for i in range(len(traindataViews)):
    if(traindataViews[i]>500000):
        traindataViews[i]=np.mean(traindataViews)

# %%
# Mean X and Y
mean_x = np.mean(traindataViews)
mean_y = np.mean(traindataDislike)

# Total Number of values
n = len(traindataViews)

# Using the formula to calculate b1 and b2
number = 0
den =0
for i in range(n):
    number+=(traindataViews[i] - mean_x)*(traindataDislike[i] - mean_y)
    den += (traindataViews[i] - mean_x) ** 2
b1 = number / den
b0 = mean_y - (b1 * mean_x)

#print coefficients
print(b1, b0)
# Out:
# 0.00039096469147745406 11.067363203677871

# %%
# Plotting values and Regression Line
plt.figure(figsize=(20,7))
max_x = np.max(traindataViews) + 100
min_x = np.min(traindataViews) - 100

#Calculating Line Values x and y
x = np.linspace(min_x, max_x,10) 
y = b0 + b1 * x

#ploting line
plt.plot(x, y, color='#58b970', label='Regression Line')
#plotting Scatter Points
plt.scatter(traindataViews, traindataDislike, c='#ef5423', label='Scatter Plot')

plt.xlabel('videoviewcount')
plt.ylabel('videodislikecount')

plt.legend()
plt.show()

# %%
ss_t = 0
ss_r = 0
for i in range(n):
    y_pred = b0 +b1 * traindataViews[i]
    ss_t += (traindataDislike[i] - mean_y)**2
    ss_r += (traindataDislike[i] - y_pred) **2
    
r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 0.006473726867982643
